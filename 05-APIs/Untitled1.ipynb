# %%
import pandas as pd
import numpy as np
import random
from sqlalchemy import create_engine

# %%
census_q12018 = pd.read_csv("../05-APIs/Census_Q1_2018.csv")

# %%
census_q12018
# Out:
#                                               Geography  \
# 0                                            U.S. TOTAL
# 1                                               Alabama
# 2                               Autauga County, Alabama
# 3                               Baldwin County, Alabama
# 4                               Barbour County, Alabama
# ...                                                 ...
# 4417  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA...
# 4418      Wausau-Stevens Point-Wisconsin Rapids, WI CSA
# 4419             Wichita-Arkansas City-Winfield, KS CSA
# 4420                    Williamsport-Lock Haven, PA CSA
# 4421                       Youngstown-Warren, OH-PA CSA
#
#      Quarterly_Establishments July_Employment August_Employment  \
# 0                   9,896,099     142,889,218       143,825,578
# 1                     125,635       1,920,931         1,936,145
# 2                         865          10,925            10,958
# ...
